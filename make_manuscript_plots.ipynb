# %% [markdown]
# # Make Plots for Manuscript

# %%
# !mkdir manuscript_plots

# %%
# Imports for main text figures
from LB51.manuscript_plots import overview_for_setup
from LB51.manuscript_plots import new_summary_part1
from LB51.manuscript_plots import new_summary_part2
from LB51.manuscript_plots import quant2
from LB51.manuscript_plots import cartoon_absorption_changes

# Imports for supplementary figures
from LB51.manuscript_plots import overview
from LB51.manuscript_plots import supplement_raw_specs
from LB51.manuscript_plots import simulations_overview
from LB51.manuscript_plots import simulations_with_enhancement
# Out:
# IMPORTING STANDARD PYTHON MODULES...
# DONE

# %%
# Fig. 2b of manuscript
overview_for_setup.overview_plot()
# Out:
# /Users/dhigley/Documents/LB51/LB51_2/LB51/LB51_get_cal_data.py:301: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   dtype = np.dtype(dtype_args)
# /Users/dhigley/Documents/LB51/LB51_2/LB51/LB51_get_cal_data.py:242: RuntimeWarning: invalid value encountered in log
#   absorption = -np.log(sam_spec_sum / no_sam_spec_sum)

# %%
# Fig. 3a and Fig. 3b of manuscript
new_summary_part1.make_figure()
# Out:
# /Users/dhigley/Documents/LB51/LB51_2/LB51/LB51_get_cal_data.py:301: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   dtype = np.dtype(dtype_args)
# /Users/dhigley/Documents/LB51/LB51_2/LB51/LB51_get_cal_data.py:242: RuntimeWarning: invalid value encountered in log
#   absorption = -np.log(sam_spec_sum / no_sam_spec_sum)
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
# Fig. 3c and 3d of manuscript
new_summary_part2.make_figure()
# Out:
# /Users/dhigley/Documents/LB51/LB51_2/LB51/LB51_get_cal_data.py:301: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   dtype = np.dtype(dtype_args)
# /Users/dhigley/Documents/LB51/LB51_2/LB51/LB51_get_cal_data.py:242: RuntimeWarning: invalid value encountered in log
#   absorption = -np.log(sam_spec_sum / no_sam_spec_sum)
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
# Fig. 4 of manuscript
quant2.quant2()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
# Bottom parts of Fig. 5
cartoon_absorption_changes.make_plots()
# Out:
# /Users/dhigley/Documents/LB51/LB51_2/LB51/LB51_get_cal_data.py:301: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   dtype = np.dtype(dtype_args)
# /Users/dhigley/Documents/LB51/LB51_2/LB51/LB51_get_cal_data.py:242: RuntimeWarning: invalid value encountered in log
#   absorption = -np.log(sam_spec_sum / no_sam_spec_sum)
# /Users/dhigley/Documents/LB51/LB51_2/LB51/LB51_get_cal_data.py:301: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   dtype = np.dtype(dtype_args)
# /Users/dhigley/Documents/LB51/LB51_2/LB51/LB51_get_cal_data.py:242: RuntimeWarning: invalid value encountered in log
#   absorption = -np.log(sam_spec_sum / no_sam_spec_sum)
# ...

# %%
# Fig. 1 of supplementary material
overview.overview_plot()
# Out:
# /Users/dhigley/Documents/LB51/LB51_2/LB51/LB51_get_cal_data.py:301: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   dtype = np.dtype(dtype_args)
# /Users/dhigley/Documents/LB51/LB51_2/LB51/LB51_get_cal_data.py:242: RuntimeWarning: invalid value encountered in log
#   absorption = -np.log(sam_spec_sum / no_sam_spec_sum)

# %%
# Fig. 2 of summplementary material
supplement_raw_specs.make_figure()
# Out:
# /Users/dhigley/Documents/LB51/LB51_2/LB51/LB51_get_cal_data.py:301: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   dtype = np.dtype(dtype_args)
# /Users/dhigley/Documents/LB51/LB51_2/LB51/LB51_get_cal_data.py:242: RuntimeWarning: invalid value encountered in log
#   absorption = -np.log(sam_spec_sum / no_sam_spec_sum)
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
# Fig. 3 of supplementary material
simulations_overview.simulations_overview()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
# Fig. 4 of supplementary material
simulations_with_enhancement.simulations_with_enhancement()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
